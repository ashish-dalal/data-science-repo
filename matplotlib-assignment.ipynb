# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# ==> Matplotlib is a data visualization library for python which is used for plotting graphical plots.
# different types of plots that can be plotted using matplotlib are:
# 1. line plot
# 2. scatter
# 3. bar
# 4. stem
# 5. step
# 6. fill_between
# 7. stackplot
# 8. histogram
# 9. histogram 2d
# 10. boxplot
# 11. errorbar
# 12. violinplot
# 13. event plot
# 14. pie chart
# 15. hexbin plot
# 16. 3D scatter plot
# 17. 3D surface
# 18. triangular 3D surfaces
# 19. 3D volumetric plot
# 18. 3D wireframe plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.subplot(2,2,4)
plt.plot(x4,y4)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.bar(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %%
box1 = np.random.normal(100,10,200)
box2 = np.random.normal(90,20,200)

plt.subplot(1,2,1)
plt.boxplot(box1)
plt.subplot(1,2,2)
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1da981587d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1da9814e110>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1da98153750>],
#  'medians': [<matplotlib.lines.Line2D at 0x1da9815ba90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1da980fc750>],
#  'means': []}
